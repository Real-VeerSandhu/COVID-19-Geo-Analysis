# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
country_wise = pd.read_csv('D:/ML_Data/SCIFAA_COVID/country_wise_latest.csv')
day_wise = pd.read_csv('D:/ML_Data/SCIFAA_COVID/day_wise.csv')
full_grouped = pd.read_csv('D:/ML_Data/SCIFAA_COVID/full_grouped.csv')
worldometer_data = pd.read_csv('D:/ML_Data/SCIFAA_COVID/worldometer_data.csv')
clean_complete = pd.read_csv('D:/ML_Data/SCIFAA_COVID/covid_19_clean_complete.csv')

# %%
print(country_wise.shape)
country_wise.head()
# Out:
# (187, 15)
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
print(day_wise.shape)
day_wise.head()
# Out:
# (188, 12)
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8
# ...

# %%
print(full_grouped.shape)
full_grouped.head()
# Out:
# (35156, 10)
#          Date Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0  2020-01-22    Afghanistan          0       0          0       0          0
# 1  2020-01-22        Albania          0       0          0       0          0
# 2  2020-01-22        Algeria          0       0          0       0          0
# 3  2020-01-22        Andorra          0       0          0       0          0
# 4  2020-01-22         Angola          0       0          0       0          0
#
#    New deaths  New recovered             WHO Region
# 0           0              0  Eastern Mediterranean
# 1           0              0                 Europe
# 2           0              0                 Africa
# 3           0              0                 Europe
# 4           0              0                 Africa

# %%
print(worldometer_data.shape)
worldometer_data.head()
# Out:
# (209, 16)
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
# 3         Russia         Europe  1.459409e+08      871894       NaN
# 4   South Africa         Africa  5.938157e+07      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0
# 3      14606.0        NaN        676357.0           NaN     180931.0
# 4       9604.0        NaN        387316.0           NaN     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# ...

# %%
a4_dims = (20, 7.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.set_style("darkgrid")
sns.scatterplot(ax=ax, data=day_wise, x='Date', y='Confirmed', hue='Deaths').set(xlabel='Date', ylabel='Confirmed Cases', xticklabels=[], title='Reported Date vs Confirmed Cases vs Deaths')
# Out:
# [Text(0, 0.5, 'Confirmed Cases'),
#  [],
#  Text(0.5, 0, 'Date'),
#  Text(0.5, 1.0, 'Reported Date vs Confirmed Cases vs Deaths')]

# %%
a4_dims = (20, 7.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.scatterplot(ax=ax, data=day_wise, x='Date', y='New cases', hue='New deaths').set(xlabel='Date', xticklabels=[], ylabel='New Cases', title='Reported Date vs New Cases vs New Deaths')
# Out:
# [Text(0, 0.5, 'New Cases'),
#  [],
#  Text(0.5, 0, 'Date'),
#  Text(0.5, 1.0, 'Reported Date vs New Cases vs New Deaths')]

# %%
list_reg = ['Canada', 'France', 'Japan', 'Italy', 'US', 'United Kingdom', 'Germany']

g7 = pd.DataFrame()
for i in list_reg:
    g7 = df.append(country_wise.loc[country_wise['Country/Region'] == i])

# %%
g7
# Out:
#      Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 32           Canada     116458    8944          0   107514        682
# 61           France     220352   30212      81212   108928       2551
# 87            Japan      31142     998      21970     8174        594
# 173              US    4290259  148011    1325804  2816444      56336
# 177  United Kingdom     301708   45844       1437   254427        688
# 65          Germany     207112    9125     190314     7673        445
# 65          Germany     207112    9125     190314     7673        445
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 32           11              0                7.68                   0.00
# 61           17            267               13.71                  36.86
# 87            0            364                3.20                  70.55
# 173        1076          27941                3.45                  30.90
# ...

# %%
a4_dims = (20, 7.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.barplot(ax=ax, data=g7, x='Country/Region', y='Confirmed', hue='Deaths').set(ylabel='Confirmed Cases', title='Country vs Confirmed Cases vs Deaths')
# Out:
# [Text(0, 0.5, 'Confirmed Cases'),
#  Text(0.5, 1.0, 'Country vs Confirmed Cases vs Deaths')]

# %%
a4_dims = (20, 7.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.barplot(ax=ax, data=g7, x='Country/Region', y='New cases', hue='New deaths').set(ylabel='New Cases', title='Country vs New Cases vs New Deaths')
# Out:
# [Text(0, 0.5, 'New Cases'),
#  Text(0.5, 1.0, 'Country vs New Cases vs New Deaths')]

# %%
a4_dims = (20, 7.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.barplot(ax=ax, data=g7, x='Country/Region', y='Deaths / 100 Cases', hue='Recovered / 100 Cases').set(title='Country vs Deaths / 100 cases vs Recovered / 100 cases')
# Out:
# [Text(0.5, 1.0, 'Country vs Deaths / 100 cases vs Recovered / 100 cases')]

# %%
a4_dims = (20, 7.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.barplot(ax=ax, data=g7, x='Country/Region', y='Confirmed last week', hue='1 week change').set(title='Country vs Weekly Changes')
# Out:
# [Text(0.5, 1.0, 'Country vs Weekly Changes')]

# %%
highest_confirmed = country_wise.sort_values(by='Confirmed', ascending=False)

# %%
top10 = highest_confirmed[0:10]

# %%
a4_dims = (20, 7.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.barplot(ax=ax, data=top10, x='Country/Region', y='Confirmed', hue='Deaths').set(title='Country vs Confirmed vs Deaths')
plt.legend(loc='upper right')

# %%
a4_dims = (20, 7.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.barplot(ax=ax, data=top10, x='Country/Region', y='Confirmed last week', hue='1 week change').set(title='Country vs Weekly Changes')
plt.legend(loc='upper right')

# %%
a4_dims = (20, 7.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.barplot(ax=ax, data=top10, x='Country/Region', y='Deaths', hue='Recovered').set(title='Country vs Deaths vs Recovered')
plt.legend(loc='upper right')
